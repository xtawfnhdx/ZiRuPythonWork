# %% [markdown]
# ## Exercise 1
#
# Create a list called ```my_first_list``` containing the following items:
#
# - The integer ```7```
# - A string containing your name
# - The Euler's number ```2.71828```
# - A list with four elements
#     - The day of your birthday as an integer
#     - The month of your birthday as a string
#     - The year of your birthday as an integer
#     - Your birthplace as a string

# %% [markdown]
# ## Exercise 2
#
# Using the ```my_first_list``` above, print out your name and Euler's number by indexing the list

# %% [markdown]
# ## Exercise 3
#
# Using list **slicing** and the ```my_first_list``` above, write a program that returns a list containing the integer ```7``` and your name

# %% [markdown]
# ## Exercise 4
#
# Using the ```my_first_list``` above, write a program that prints out the following:
#
# ```I was born in {birthplace} on the {birth_day} {birth_month} {birth_year}```
#
# where the details of your birthday should be obtained from the ```my_first_list``` above. You may create additional variables if needed.

# %% [markdown]
# ## Exercise 5
# Given the following basket:
#
# | **Good**      | **Price**       | **Quantity** |
# | :------------ | :------------:  | :----------: |
# | Cola          | 1.25            | 5            |
# | Water         | 0.75            | 7            |
# | Chocolate     | 3               | 4            |
#
# and a **nested** list defined by
#
# ```python
# basket = [[1.25, 5], [0.75, 7], [3, 4]]
# ```
#
# compute and display the total cost of the basket.

# %% [markdown]
# ## Exercise 6
#
# Write a program that replaces your name with your surname in ```my_first_list``` and prints the new updated list.

# %% [markdown]
# ## Exercise 7
#
# Consider the example seen in class where we added crisps to our basket
#
# ```python
# # For each good, create a list containing the price and quantity purchased
# cola      = [1.25, 5]
# water     = [0.75, 7]
# chocolate = [3, 4]
#
# # Store all information in one variable
# basket = [cola, water, chocolate]
#
# # Store the price and quantity of crisps in a list
# crisps = [1.95, 3]
#
# # Add the crisps to your basket list
# basket.append(crisps)
#
# # Check that the crisps are there
# print(basket)
# ```
# Repeat the example above using the ```list.extend()``` method instead of the ```list.append()``` method.
#
# Do you notice any difference in the resulting ```basket``` list? What's the difference between the two methods?

# %%
# Run this cell to get help on the list.extend() method
help(list.extend)

# %%
# Use this cell to write your program

# %% [markdown]
# ## Exercise 8
# Consider the list ```basket``` generated by the program below
#
# ```python
# # For each good, create a list containing the price and quantity purchased
# cola      = [1.25, 5]
# water     = [0.75, 7]
# chocolate = [3, 4]
# crisps    = [1.95, 3]
#
# # Store all information in one variable
# basket = [cola, water, chocolate, crisps]
# ```
#
# Let's say that you want to remove chocolate, however you forgot where the chocolate is in the basket, that is **you don't know the corresponding index**.
#
# Use the ```list.remove()``` method to do so.

# %%
# Run this cell to get help on the list.remove() method
help(list.remove)

# %%
# Use this cell to write your program

# %% [markdown]
# ## Exercise 9
#
# Create a tuple ```my_first_tuple``` with the following values
#
# - The integer ```5```
# - The string ```Economics```
# - The list ```my_first_list```

# %% [markdown]
# ## Exercise 10
#
# Using ```my_first_tuple```, try to replace ```Economics``` with ```Sociology``` using the indexing notation for lists. What do you observe?

# %% [markdown]
# ## Exercise 11
#
# Create a dictionary ```my_car``` containing the model, make, body style, and year of your car. If you do not own a car, insert the details of your dream car.

# %% [markdown]
# ## Exercise 12
#
# Using the dictionary ```my_car``` above, write a program that prints out the following:
#
# ```My car is a {body_style} {model} made by {make} in {year}```

# %% [markdown]
# ## Exercise 13
#
# Update the dictionary to the car of your dreams and print out
#
# ```I upgraded to a {body_style} {model} made by {make} in {year}```

# %% [markdown]
# ## Exercise 14
#
# Repeat the exercise above using the ```dict.update()``` method.

# %%
# Run this cell to get help on the dict.update() method
dict.update?

# %%
# Use this cell to write your program

# %% [markdown]
# ## Exercise 15
#
# Given the following dictionary
#
# ```python
# basket = {
#           "cola"     :  {"price": 1.25, "quantity": 5},
#           "water"    :  {"price": 0.75, "quantity": 7},
#           "chocolate":  {"price": 3   , "quantity": 4},
# }
# ```
#
# compute and print the cost of the basket.

# %% [markdown]
# ## Exercise 16
#
# Given the list
#
# ```python
# subjects = ["Economics", "Computer science", "Law", "History"]
# ```
#
# write a program that prints out each subject using a for loop.

# %% [markdown]
# ## Exercise 17
#
# Given the string ```Python``` , write a program that prints out
#
# ```
# Letter 1 is P
# Letter 2 is y
# ...
# Letter 6 is n
# ```

# %% [markdown]
# ## Exercise 18
#
# Repeat the exercise above using the ```enumerate()``` function.

# %%
# Run this cell to get help on the enumerate() function
help(enumerate)

# %%
# Use this cell to write your program

# %% [markdown]
# ## Exercise 19
# Given the following basket
#
# | **Good**      | **Price**       | **Quantity** |
# | :------------ | :------------:  | :----------: |
# | Cola          | 1.25            | 5            |
# | Water         | 0.75            | 7            |
# | Chocolate     | 3               | 4            |
#
# and the following lists
#
# ```python
# prices     = [1.25, 0.75, 3]
# quantities = [5, 7, 4]
# ```
#
# Compute and display the total cost of the basket **using a for loop**.

# %% [markdown]
# ## Exercise 20
#
# Given the lists
#
# ```
# cities  = ["London", "Berlin", "Roma"]
# countries = ["UK", "Germany", "Italia"]
# ```
#
# write a program that prints
#
# ```{city} is in {country}```
#
# with a for loop.

# %% [markdown]
# ## Exercise 21
#
# Repeat the exercise above using the ```zip()``` function.

# %%
# Run this cell to get help on the zip() function
help(zip)

# %%
# Use this cell to write your program

# %% [markdown]
# ## Exercise 22
#
# Given the lists
#
# ```
# shoes    = ["sneakers", "running", "classic"]
# t_shirts = ["red", "white", "blue"]
# ```
#
# Write a program that prints out all combinations of shoes and t-shirts from two lists. Use a nested loop.

# %% [markdown]
# ## Exercise 23
#
# Execute the ```while loop``` below. What do you observe?

# %%
while True:
    print("Infinite loop!")

# %% [markdown]
# ## Exercise 24
#
# Given the two lists below:

# %%
years = list(range(1980,2000))
print(years)

inflation = [20.82, 18.79, 17.54, 15.10, 10.76, 9.17, 7.49, 6.01, 6.65, 6.20, 8.91, 7.58, 4.37, 3.89, 3.54, 4.93, 4.55, 2.60, 2.53, 1.62]
print(inflation)

# %% [markdown]
# Create a dictionary where years are the keys and inflation are the values. Print out all the years and correspondent inflation values using a for loop.

# %% [markdown]
# # Additional exercises

# %% [markdown]
# ## Exercise
#
# Create a list of strings and convert it into a sentence with ```str.join()``` method

# %%
# Run this cell to get help on the str.join() method
help(str.join)

# %%
# Use this cell to write your program

# %% [markdown]
# ## Exercise
#
# Get back the list with ```str.split()``` method

# %%
# Run this cell to get help on the str.split() method
help(str.split)

# %%
# Use this cell to write your program

# %% [markdown]
# ## Exercise
# Create any list. Loop over and print selected items in the list, e.g. only elements from 3 to 5.
#
# Use two approaches:
#
# - Slice the list before the loop and put in place of the iterable
# - Use the ```range()``` function from 2 to 4. Check ```help(range)``` first

# %% [markdown]
# ## Exercise
#
# Repeat the times table Exercise 14 in Workshop 6 with for loop.

# %% [markdown]
# ## Exercise
#
# Given a list containing strings, write a program that loops through the list first and characters in strings then.
